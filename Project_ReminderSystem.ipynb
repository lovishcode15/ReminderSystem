# %% [markdown]
# <a href="https://colab.research.google.com/github/lovishcode15/ReminderSystem/blob/main/Project_ReminderSystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def reminder(set_hour,set_minute):
    hour=0
    minute=0
    while hour<=24:
        while minute<=60:
            if hour==set_hour and minute==set_minute:
                print(enter_reminder,"at",enter_hr,":",enter_min)
                return
            minute=minute+1
        minute=0
        hour=hour+1


    print("no reminder")


enter_reminder=input("enter a task:")
enter_hr=int(input(("enter a hour: ")))
enter_min=int(input("enter a minutes:"))
reminder(enter_hr,enter_min)
# Out:
# enter a task:Discussion on reddit
# enter a hour: 8
# enter a minutes:00
# Discussion on reddit at 8 : 0
